# %%
from bs4 import BeautifulSoup

# %%
chat = r"""<body class="animation-level-2 rtl fa has-chat"><!--[if IE]>
<p class="browserupgrade">You are using an <strong>outdated</strong> browser. Please <a href="https://browsehappy.com/">upgrade
    your browser</a> to improve your experience and security.</p>
<![endif]--><div class="whole" id="auth-pages" style="display:none"><div class="scrollable scrollable-y"><div class="tabs-container auth-pages__container" data-animation="tabs"><div class="tabs-tab page-sign"><div class="container"><div class="auth-image"><svg class="sign-logo" xmlns="http://www.w3.org/2000/svg" width="160" height="160" viewBox="0 0 0.28 0.29" style="shape-rendering:geometricPrecision;text-rendering:geometricPrecision;image-rendering:optimizeQuality;fill-rule:evenodd;clip-rule:evenodd"><style>.fil0{fill:#ef7f1a}</style><use href="#logo"></use></svg></div></div></div><div class="tabs-tab page-signQR"><div class="container center-align"><div class="auth-image"></div></div></div><div class="tabs-tab page-authCode"><div class="container center-align"><div class="auth-image"></div><div class="phone-wrapper"><h4 class="phone"></h4><span class="phone-edit tgico-edit"></span></div><p class="subtitle sent-type"></p><div class="input-wrapper"></div></div></div><div class="tabs-tab page-password"></div><div class="tabs-tab page-signUp"></div></div></div></div><div class="whole page-chats" style="" id="page-chats"><svg style="position:absolute;top:-10000px;left:-10000px"><defs id="svg-defs"><path id="message-tail" d="M1.00002881,1.03679295e-14 L7,0 L7,17 C6.8069969,14.1607017 6.12380234,11.2332513 4.95041634,8.21764872 C4.04604748,5.89342034 2.50413132,3.73337411 0.324667862,1.73751004 L0.324652538,1.73752677 C-0.0826597201,1.36452676 -0.110475289,0.731958677 0.262524727,0.324646419 C0.451952959,0.117792698 0.719544377,1.0985861e-14 1.00002881,1.04360964e-14 Z"></path><path id="logo" class="fil0" d="M0.08 0l0.12 0c0.05,0 0.08,0.04 0.08,0.08l0 0.04c-0.04,0.02 -0.08,0.11 -0.14,0.09 0,0 -0.01,0.02 -0.01,0.03 -0.02,-0.01 -0.05,-0.03 -0.04,-0.06 -0.04,-0.02 -0.01,-0.07 0.02,-0.08 0.06,-0.04 0.14,-0.01 0.09,0.02 -0.03,0.02 -0.08,0.03 -0.08,-0.01 -0.01,0 -0.02,0.03 0,0.05 -0.02,0.01 -0.02,0.04 0,0.06 0.02,-0.05 0.09,-0.05 0.11,-0.11 0.02,-0.04 -0.01,-0.09 -0.07,-0.08 -0.04,0 -0.09,0.04 -0.11,0.08 -0.02,0.05 -0.01,0.11 0.03,0.14 0.05,0.04 0.11,0.01 0.14,-0.04 0.02,-0.02 0.04,-0.05 0.06,-0.07l0 0.07c0,0.04 -0.03,0.08 -0.08,0.08l-0.12 0c-0.04,0 -0.08,-0.04 -0.08,-0.08l0 -0.13c0,-0.04 0.04,-0.08 0.08,-0.08z"></path><path id="poll-line" d="M4.47,5.33v13.6c0,4.97,4.03,9,9,9h458.16"></path><path id="check" fill="none" d="M 4.7071 12.2929 l 5 5 c 0.3905 0.3905 1.0237 0.3905 1.4142 0 l 11 -11"></path><path id="verified-background" d="M12.3 2.9c.1.1.2.1.3.2.7.6 1.3 1.1 2 1.7.3.2.6.4.9.4.9.1 1.7.2 2.6.2.5 0 .6.1.7.7.1.9.1 1.8.2 2.6 0 .4.2.7.4 1 .6.7 1.1 1.3 1.7 2 .3.4.3.5 0 .8-.5.6-1.1 1.3-1.6 1.9-.3.3-.5.7-.5 1.2-.1.8-.2 1.7-.2 2.5 0 .4-.2.5-.6.6-.8 0-1.6.1-2.5.2-.5 0-1 .2-1.4.5-.6.5-1.3 1.1-1.9 1.6-.3.3-.5.3-.8 0-.7-.6-1.4-1.2-2-1.8-.3-.2-.6-.4-.9-.4-.9-.1-1.8-.2-2.7-.2-.4 0-.5-.2-.6-.5 0-.9-.1-1.7-.2-2.6 0-.4-.2-.8-.4-1.1-.6-.6-1.1-1.3-1.6-2-.4-.4-.3-.5 0-1 .6-.6 1.1-1.3 1.7-1.9.3-.3.4-.6.4-1 0-.8.1-1.6.2-2.5 0-.5.1-.6.6-.6.9-.1 1.7-.1 2.6-.2.4 0 .7-.2 1-.4.7-.6 1.4-1.2 2.1-1.7.1-.2.3-.3.5-.2z"></path><path id="verified-check" d="M16.4 10.1l-.2.2-5.4 5.4c-.1.1-.2.2-.4 0l-2.6-2.6c-.2-.2-.1-.3 0-.4.2-.2.5-.6.7-.6.3 0 .5.4.7.6l1.1 1.1c.2.2.3.2.5 0l4.3-4.3c.2-.2.4-.3.6 0 .1.2.3.3.4.5.2 0 .3.1.3.1z"></path><symbol id="message-tail-filled" viewBox="0 0 11 20"><g transform="translate(9 -14)" fill="inherit" fill-rule="evenodd"><path d="M-6 16h6v17c-.193-2.84-.876-5.767-2.05-8.782-.904-2.325-2.446-4.485-4.625-6.48A1 1 0 01-6 16z" transform="matrix(1 0 0 -1 0 49)" id="corner-fill" fill="inherit"></path></g></symbol></defs></svg><div id="main-columns" class="tabs-container" data-animation="navigation" style=""><div class="tabs-tab chatlist-container sidebar sidebar-left main-column" id="column-left"><div class="sidebar-slider tabs-container" data-animation="navigation"><div class="tabs-tab sidebar-slider-item item-main active"><div class="sidebar-header"><div class="sidebar-header__btn-container"><div class="animated-menu-icon"></div><div class="btn-icon btn-menu-toggle rp sidebar-tools-button is-visible"><div class="c-ripple"></div><div class="btn-menu bottom-right has-footer"><div class="btn-menu-item tgico-saved rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">پیام های ذخیره شده</span></div><div class="btn-menu-item tgico-archive rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">گفتگو های ذخیره شده</span></div><div class="btn-menu-item tgico-user rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">مخاطبین</span></div><div class="btn-menu-item tgico-settings rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">تنظیمات</span></div><div class="btn-menu-item tgico-darkmode rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">حالت شب</span><label class="checkbox-field checkbox-without-caption checkbox-field-toggle"><input class="checkbox-field-input" type="checkbox"><div class="checkbox-toggle"></div></label></div><div class="btn-menu-item tgico-animations rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">انیمیشن</span><label class="checkbox-field checkbox-without-caption checkbox-field-toggle"><input class="checkbox-field-input" type="checkbox"><div class="checkbox-toggle"></div></label></div><div class="btn-menu-item tgico-direction rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">راست چین</span><label class="checkbox-field checkbox-without-caption checkbox-field-toggle"><input class="checkbox-field-input" type="checkbox"><div class="checkbox-toggle"></div></label></div><div class="btn-menu-item tgico-services rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">خدمات ایتا</span></div><div class="btn-menu-item tgico-admin rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">ایتای من</span></div><div class="btn-menu-item tgico-stop rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">بارگذاری مجدد</span></div><a href="https://web.eitaa.com" target="_blank" rel="noopener noreferrer" class="btn-menu-footer"><span class="btn-menu-footer-text">Eitaa Web 4.6.12 (78)</span></a></div></div><div class="btn-icon sidebar-back-button"></div><span class="i18n eitaa-title">ایتا</span></div><div class="input-search" id="main-search">
      <input type="text" autocomplete="off" class="input-field-input i18n input-search-input" dir="auto" placeholder="جستجو">
      <div class="input-field-border"></div><i class="tgico tgico-search"></i><i class="tgico btn-icon tgico-close"></i></div></div><div class="sidebar-content transition zoom-fade"><div class="transition-item active" id="chatlist-container"><div class="connection-status-bottom"><div class="folders-tabs-scrollable menu-horizontal-scrollable"><div class="scrollable scrollable-x"><nav class="menu-horizontal-div" id="folders-tabs"><div class="menu-horizontal-div-item rp active"><span><span class="text-super"><span class="i18n">همه</span></span><div class="badge badge-20 badge-primary"></div><i></i></span><div class="c-ripple"></div></div><div class="menu-horizontal-div-item rp"><span><span class="text-super" dir="auto">شخصی</span><div class="badge badge-20 badge-primary badge-gray"></div><i></i></span><div class="c-ripple"></div></div><div class="menu-horizontal-div-item rp"><span><span class="text-super" dir="auto">کانال</span><div class="badge badge-20 badge-primary badge-gray">1</div><i></i></span><div class="c-ripple"></div></div><div class="menu-horizontal-div-item rp"><span><span class="text-super" dir="auto">گروه</span><div class="badge badge-20 badge-primary badge-gray"></div><i></i></span><div class="c-ripple"></div></div><div class="menu-horizontal-div-item rp"><span><span class="text-super" dir="auto">مدیر</span><div class="badge badge-20 badge-primary badge-gray"></div><i></i></span><div class="c-ripple"></div></div><div class="menu-horizontal-div-item rp"><span><span class="text-super" dir="auto">نخوانده</span><div class="badge badge-20 badge-primary badge-gray"></div><i></i></span><div class="c-ripple"></div></div></nav></div></div><div class="tabs-container" id="folders-container" data-animation="tabs"><div class="scrollable scrollable-y tabs-tab chatlist-parts active" data-filter-id="0"><div class="chatlist-top"><ul class="ads-dialog-box" data-autonomous="0"><li class="ads-active rp" data-id="145728" data-username="zekrenik" data-msg-id="49506"><div class="c-ripple"></div><a class="anchor-url"></a><avatar-element class="dialog-avatar avatar-54" data-color=""><img class="avatar-photo" src="blob:https://web.eitaa.com/2fe61fcf-be2d-4d36-931d-6ad60fb9209c"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="peer-title" dir="auto">مُعجزه خواندن آيَتُ الْكُرسى‌❤</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time">تبلیغات</span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto">زیباترین اَحادیث ، رِوایات کاربردی💚</span></p></div></li></ul><ul class="chatlist" data-autonomous="0"><li class="rp chatlist-chat is-muted active" data-peer-id="-51577627"><div class="c-ripple"></div><avatar-element dialog="1" peer="-51577627" dir="auto" data-color="green" class="dialog-avatar avatar-54">کآ</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-group"></span><span class="peer-title" dir="auto" data-peer-id="-51577627" data-dialog="1" data-only-first-name="0" data-plain-text="0">کنترل کیفیت و آزمایشگاه </span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">۱۲:۰۲ قبل‌ازظهر</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><b><span class="peer-title" dir="auto" data-peer-id="33891335" data-only-first-name="1">اسماعیل</span>: </b>سلام کوره 1 ساعت 24 4.07 صدم شد...
کوره 2 ساعت 24 3.97 شد...</span></p></div></li><li class="rp chatlist-chat is-muted" data-peer-id="-8804588"><div class="c-ripple"></div><avatar-element dialog="1" peer="-8804588" dir="auto" data-color="" class="dialog-avatar avatar-54"><img class="avatar-photo" src="blob:https://web.eitaa.com/5e99026d-ce8a-48a2-ab00-7caa0370ff29"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-channel"></span><span class="peer-title" dir="auto" data-peer-id="-8804588" data-dialog="1" data-only-first-name="0" data-plain-text="0"> مبارکه آنلاین</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">جمعه</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><span><i><span class="i18n">استیکر</span></i></span></span></p><div class="dialog-subtitle-badge badge badge-24 is-visible unread">2</div><p></p></div></li><li class="rp chatlist-chat" data-peer-id="333000"><div class="c-ripple"></div><avatar-element dialog="1" peer="333000" dir="auto" data-color="" class="dialog-avatar avatar-54"><img class="avatar-photo" src="blob:https://web.eitaa.com/97e88422-d25b-4c06-9d2b-cf97660ea1b2"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="333000" data-dialog="1" data-only-first-name="0" data-plain-text="0">ایتا</span><svg viewBox="0 0 24 24" width="24" height="24" class="verified-icon"><use href="#verified-background" class="verified-background"></use><use href="#verified-check" class="verified-check"></use></svg></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">جمعه</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><img src="assets/img/emoji/26a0.png" class="emoji" alt="⚠️">ورود به حساب

کاربر گرامی: در تاریخ 1404/09/07 ساعت 18:59 یک ورود به حساب کاربری شما انجام شده است...</span></p></div></li><li class="rp chatlist-chat" data-peer-id="-25302131"><div class="c-ripple"></div><avatar-element dialog="1" peer="-25302131" dir="auto" data-color="" class="dialog-avatar avatar-54"><img class="avatar-photo" src="blob:https://web.eitaa.com/b8881cc2-9b3f-49c4-8188-cf6326226bf0"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-channel"></span><span class="peer-title" dir="auto" data-peer-id="-25302131" data-dialog="1" data-only-first-name="0" data-plain-text="0">ساپفو</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">چهارشنبه</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><i>bki_manual_registration.pdf</i>, #تبلیغات

<img src="assets/img/emoji/1f4a0.png" class="emoji" alt="💠"> آزمون استخدامی بانک کشاورزی سال ۱۴۰۴

ثبت‌نام: چهارشنبه 5 آذرماه تا جمعه 14 آذرماه 1404...</span></p></div></li><li class="rp chatlist-chat" data-peer-id="-91901542"><div class="c-ripple"></div><avatar-element dialog="1" peer="-91901542" dir="auto" data-color="blue" class="dialog-avatar avatar-54">ثو</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-channel"></span><span class="peer-title" dir="auto" data-peer-id="-91901542" data-dialog="1" data-only-first-name="0" data-plain-text="0">ثبت وقایع</span></span><span class="dialog-title-details"><span class="message-status sending-status"><i class="sending-status-icon tgico-check"></i></span><span class="message-time"><span class="i18n">چهارشنبه</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto">چهارشنبه
1404/09/05
1. احمد پور از 12 شب تا 6 صبح ول
2. نصف روز بار رو ریجکت و با ریجکت های قبلی قاط...</span></p></div></li><li class="rp chatlist-chat" data-peer-id="-56148983"><div class="c-ripple"></div><avatar-element dialog="1" peer="-56148983" dir="auto" data-color="violet" class="dialog-avatar avatar-54">نآ</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-group"></span><span class="peer-title" dir="auto" data-peer-id="-56148983" data-dialog="1" data-only-first-name="0" data-plain-text="0">ناظرین کیفی - فولاد سنگ ( آهک) </span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">چهارشنبه</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><b><span class="peer-title" dir="auto" data-peer-id="7002842" data-only-first-name="1">محمد رضا</span>: </b></span></p><div class="dialog-subtitle-media media-container"><img class="media-photo" src="blob:https://web.eitaa.com/dff4caa7-40eb-41ff-8a77-75ad6687dd90"></div>گزارش روزانه

با سلام؛ 
احتراماً به استحضار می‌رساند باتوجه به تعمیرات خط آهک ، بار مطلوب درحال حاضر...<p></p></div></li><li class="rp chatlist-chat" data-peer-id="-71790785"><div class="c-ripple"></div><avatar-element dialog="1" peer="-71790785" dir="auto" data-color="green" class="dialog-avatar avatar-54">I</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-group"></span><span class="peer-title" dir="auto" data-peer-id="-71790785" data-dialog="1" data-only-first-name="0" data-plain-text="0">Inspection</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">چهارشنبه</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><b><span class="peer-title" dir="auto" data-peer-id="7002842" data-only-first-name="1">محمد رضا</span>: </b>تاریخ ۰۵ آذر ماه ۱۴۰۴ ساعت دوازده :
سایز بالای ۶۰ میلی‌متر : 0
سایز بالای ۴۰ میلی‌متر : 43.7
سایز ...</span></p></div></li><li class="rp chatlist-chat" data-peer-id="7002842"><div class="c-ripple"></div><avatar-element dialog="1" peer="7002842" dir="auto" data-color="red" class="dialog-avatar avatar-54">مر</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="7002842" data-dialog="1" data-only-first-name="0" data-plain-text="0">محمد رضا</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">چهارشنبه</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto">گزارش فوق العاده

با سلام؛ 
احتراماً به استحضار می‌رساند باتوجه به تعمیرات خط آهک ، بار مطلوب درحال ...</span></p></div></li><li class="rp chatlist-chat" data-peer-id="-83769413"><div class="c-ripple"></div><avatar-element dialog="1" peer="-83769413" dir="auto" data-color="red" class="dialog-avatar avatar-54">ب</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-group"></span><span class="peer-title" dir="auto" data-peer-id="-83769413" data-dialog="1" data-only-first-name="0" data-plain-text="0">بازرسی</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">چهارشنبه</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><b><span class="peer-title" dir="auto" data-peer-id="68034713" data-only-first-name="1">mohamad</span>: </b><i>1404-09-04.pdf</i></span></p></div></li><li class="rp chatlist-chat" data-peer-id="20319777"><div class="c-ripple"></div><avatar-element dialog="1" peer="20319777" dir="auto" data-color="" class="dialog-avatar avatar-54"><img class="avatar-photo" src="blob:https://web.eitaa.com/1f0c5ceb-df6f-4776-8338-3c8d58cc6590"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="20319777" data-dialog="1" data-only-first-name="0" data-plain-text="0">ابراهیم صباحی</span></span><span class="dialog-title-details"><span class="message-status sending-status"><i class="sending-status-icon tgico-checks"></i></span><span class="message-time"><span class="i18n">۱ آذر</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto">بله یکی یکی خودم نشستم چک کردم</span></p></div></li><li class="rp chatlist-chat" data-peer-id="-92407412"><div class="c-ripple"></div><avatar-element dialog="1" peer="-92407412" dir="auto" data-color="pink" class="dialog-avatar avatar-54">a<img src="assets/img/emoji/1f916.png" class="emoji" alt="🤖"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-group"></span><span class="peer-title" dir="auto" data-peer-id="-92407412" data-dialog="1" data-only-first-name="0" data-plain-text="0">avAs <img src="assets/img/emoji/1f916.png" class="emoji" alt="🤖"> </span></span><span class="dialog-title-details"><span class="message-status sending-status"><i class="sending-status-icon tgico-check"></i></span><span class="message-time"><span class="i18n">۲۷ آبان</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><b><span class="i18n">شما</span>: </b>https://eitaa.com/joinchat/108266882C246d7f19d2</span></p></div></li><li class="rp chatlist-chat" data-peer-id="68034713"><div class="c-ripple"></div><avatar-element dialog="1" peer="68034713" dir="auto" data-color="blue" class="dialog-avatar avatar-54">m</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="68034713" data-dialog="1" data-only-first-name="0" data-plain-text="0">mohamad</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">۲۷ آبان</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto">https://projecteuler.net/problem=50</span></p></div></li><li class="rp chatlist-chat" data-peer-id="3032351"><div class="c-ripple"></div><avatar-element dialog="1" peer="3032351" dir="auto" data-color="red" class="dialog-avatar avatar-54">بآ</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="3032351" data-dialog="1" data-only-first-name="0" data-plain-text="0">بهنام  ابولقاسمی آزمایشگاه</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">۲۶ آبان</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"></span></p><div class="dialog-subtitle-media media-container"><img class="media-photo" src="blob:https://web.eitaa.com/4d11da75-9f78-4384-af96-ac43c4d802b8"></div><img src="assets/img/emoji/1f4a2.png" class="emoji" alt="💢"> اطلاع رسانی سرمایه‌های انسانی و پشتیبانی فولاد سنگ مبارکه <img src="assets/img/emoji/1f447.png" class="emoji" alt="👇">
https://eitaa.com/Hrfooladsang<p></p></div></li><li class="rp chatlist-chat" data-peer-id="53265233"><div class="c-ripple"></div><avatar-element dialog="1" peer="53265233" dir="auto" data-color="red" class="dialog-avatar avatar-54"><img src="assets/img/emoji/1fac0.png" class="emoji" alt="🫀"><img src="assets/img/emoji/1fac0.png" class="emoji" alt="🫀"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="53265233" data-dialog="1" data-only-first-name="0" data-plain-text="0"><img src="assets/img/emoji/1fac0.png" class="emoji" alt="🫀"> نفسم <img src="assets/img/emoji/1fac0.png" class="emoji" alt="🫀"></span></span><span class="dialog-title-details"><span class="message-status sending-status"><i class="sending-status-icon tgico-checks"></i></span><span class="message-time"><span class="i18n">۱۹ آبان</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto">https://www.jajiga.com/room/3277229?gstnum=2&amp;chin=2025-11-12&amp;chout=2025-11-15</span></p></div></li><li class="rp chatlist-chat" data-peer-id="12202908"><div class="c-ripple"></div><avatar-element dialog="1" peer="12202908" dir="auto" data-color="cyan" class="dialog-avatar avatar-54">K</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="12202908" data-dialog="1" data-only-first-name="0" data-plain-text="0">Khodam</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">۱۴ آبان</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><i>1404 - سالیانه.xlsx</i></span></p></div></li><li class="rp chatlist-chat" data-peer-id="59440203"><div class="c-ripple"></div><avatar-element dialog="1" peer="59440203" dir="auto" data-color="cyan" class="dialog-avatar avatar-54">خع</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="59440203" data-dialog="1" data-only-first-name="0" data-plain-text="0">خانم  عظیمی</span></span><span class="dialog-title-details"><span class="message-status sending-status"><i class="sending-status-icon tgico-checks"></i></span><span class="message-time"><span class="i18n">۱۰ آبان</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><img src="assets/img/emoji/1f64f.png" class="emoji" alt="🙏"></span></p></div></li><li class="rp chatlist-chat is-muted" data-peer-id="-62255091"><div class="c-ripple"></div><avatar-element dialog="1" peer="-62255091" dir="auto" data-color="green" class="dialog-avatar avatar-54">F</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-group"></span><span class="peer-title" dir="auto" data-peer-id="-62255091" data-dialog="1" data-only-first-name="0" data-plain-text="0">Family</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">۱۹ فروردین</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><b><span class="peer-title" dir="auto" data-peer-id="19434173" data-only-first-name="1">zahra</span>: </b></span></p><div class="dialog-subtitle-media media-container"><span class="tgico-play"></span><img class="media-photo" src="blob:https://web.eitaa.com/b7fa6ae4-ff4c-4485-b9a5-1532d7c44952"></div><i><span class="i18n">ویدیو</span></i><p></p></div></li><li class="rp chatlist-chat" data-peer-id="5666431"><div class="c-ripple"></div><avatar-element dialog="1" peer="5666431" dir="auto" data-color="orange" class="dialog-avatar avatar-54">m</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="5666431" data-dialog="1" data-only-first-name="0" data-plain-text="0">maman</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">۱ آبان</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto">مالک خودرو به شماره  شخصي  ايران 43 ــ  479ط11 بعلت تخلف تجاوز از سرعت مجاز تا 10 کيلومتر
 در تاريخ ...</span></p></div></li><li class="rp chatlist-chat" data-peer-id="19434173"><div class="c-ripple"></div><avatar-element dialog="1" peer="19434173" dir="auto" data-color="" class="dialog-avatar avatar-54"><img class="avatar-photo" src="blob:https://web.eitaa.com/be10a568-4497-4a76-b26a-48b0132ab764"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="19434173" data-dialog="1" data-only-first-name="0" data-plain-text="0">zahra</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">۱ آبان</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><img src="assets/img/emoji/1f339.png" class="emoji" alt="🌹"><img src="assets/img/emoji/2764.png" class="emoji" alt="❤️"><img src="assets/img/emoji/1f490.png" class="emoji" alt="💐"></span></p></div></li><li class="rp chatlist-chat" data-peer-id="-33427709"><div class="c-ripple"></div><avatar-element dialog="1" peer="-33427709" dir="auto" data-color="" class="dialog-avatar avatar-54"><img class="avatar-photo" src="blob:https://web.eitaa.com/ee3dc5cd-2746-4b46-b4d8-4896936273ad"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-group"></span><span class="peer-title" dir="auto" data-peer-id="-33427709" data-dialog="1" data-only-first-name="0" data-plain-text="0">پروژه فولاد مبارکه</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"><span class="i18n">۳۰ مهر</span></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><b><span class="peer-title" dir="auto" data-peer-id="20319777" data-only-first-name="1">ابراهیم</span>: </b>باسلام خدمت همکاران محترم
با توجه به تغییر حساب شرکت از پاسارگاد به ملی، چنانچه در بانک ملی حساب دار...</span></p></div></li></ul></div><div class="chatlist-bottom"></div></div><div class="scrollable scrollable-y tabs-tab chatlist-parts" data-filter-id="2"><div class="chatlist-top"><ul class="chatlist" data-autonomous="0"></ul></div><div class="chatlist-bottom"></div></div><div class="scrollable scrollable-y tabs-tab chatlist-parts" data-filter-id="3"><div class="chatlist-top"><ul class="chatlist" data-autonomous="0"></ul></div><div class="chatlist-bottom"></div></div><div class="scrollable scrollable-y tabs-tab chatlist-parts" data-filter-id="4"><div class="chatlist-top"><ul class="chatlist" data-autonomous="0"></ul></div><div class="chatlist-bottom"></div></div><div class="scrollable scrollable-y tabs-tab chatlist-parts" data-filter-id="5"><div class="chatlist-top"><ul class="chatlist" data-autonomous="0"></ul></div><div class="chatlist-bottom"></div></div><div class="scrollable scrollable-y tabs-tab chatlist-parts" data-filter-id="6"><div class="chatlist-top"><ul class="chatlist" data-autonomous="0"></ul></div><div class="chatlist-bottom"></div></div></div></div></div><div class="transition-item sidebar-search" id="search-container"></div><div class="btn-circle rp btn-corner z-depth-1 btn-menu-toggle animated-button-icon" id="new-menu">
    <span class="tgico tgico-newchat_filled"></span>
    <span class="tgico tgico-close"></span>
    <div class="c-ripple"></div><div class="btn-menu top-left"><div class="btn-menu-item tgico-newchannel rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">کانال جدید</span></div><div class="btn-menu-item tgico-newgroup rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">گروه جدید</span></div><div class="btn-menu-item tgico-newprivate rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">پیام جدید</span></div></div></div></div></div></div></div><div class="tabs-tab main-column" id="column-center"><div class="chats-container tabs-container" data-animation="navigation"><div class="chat tabs-tab active type-chat"><div class="chat-background"><div class="chat-background-item is-pattern is-visible"><canvas width="50" height="50" data-colors="#dbddbb,#6ba587,#d5d88d,#88b884" class="chat-background-item-canvas chat-background-item-color-canvas"></canvas><canvas data-original-height="633" width="647" height="633" class="chat-background-item-canvas chat-background-item-pattern-canvas" style="--opacity-max: 0.5;"></canvas></div></div><div class="sidebar-header topbar" data-floating="0" style="--utils-width: 96px;"><button class="btn-icon tgico-left sidebar-close-button"></button><div class="chat-info"><div class="person"><avatar-element dialog="1" class="avatar-42 person-avatar" peer="-51577627" dir="auto" data-color="green">کآ</avatar-element><div class="content"><div class="top"><div class="user-title"><span class="peer-title" dir="auto" data-peer-id="-51577627" data-dialog="1">کنترل کیفیت و آزمایشگاه </span></div></div><div class="bottom"><div class="info"><span class="i18n">⁨8⁩ عضو</span></div></div></div></div></div><div class="chat-utils"><div class="pinned-message pinned-container hide"><button class="pinned-container-close pinned-message-close btn-icon tgico-close"></button><div class="pinned-container-wrapper rp"><div class="c-ripple"></div><div class="pinned-message-border"><div class="pinned-message-border-wrapper-1" style=""></div></div><div class="pinned-message-content pinned-container-content"><div class="animated-super pinned-message-media-container"></div><div class="pinned-message-title pinned-container-title" dir="auto"><span class="i18n">پیام سنجاق شده</span> <div class="animated-counter"></div></div><div class="pinned-message-subtitle pinned-container-subtitle" dir="auto"><div class="animated-super"></div></div></div><div class="pinned-container-wrapper-utils"><button class="btn-icon tgico-pinlist pinned-container-close pinned-message-pinlist"></button><button class="pinned-container-close pinned-message-close btn-icon tgico-close"></button></div></div></div><button class="btn-primary btn-color-primary chat-join hide rp"><span class="i18n">پیوستن</span></button><button class="btn-icon tgico-pinlist rp"><div class="c-ripple"></div></button><button class="btn-icon tgico-mute rp hide" style="display: none;"><div class="c-ripple"></div></button><button class="btn-icon tgico-search rp"><div class="c-ripple"></div></button><div class="btn-icon tgico-more btn-menu-toggle rp"><div class="c-ripple"></div><div class="btn-menu bottom-left"><div class="btn-menu-item tgico-search rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">جستجو</span></div><div class="btn-menu-item tgico-mute rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">بی‌صدا کردن</span></div><div class="btn-menu-item tgico-unmute rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">صدادار کردن</span></div><div class="btn-menu-item tgico-comments rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">مشاهده بحث</span></div><div class="btn-menu-item tgico-select rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">انتخاب پیام ها</span></div><div class="btn-menu-item tgico-select rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">پاک کردن انتخاب</span></div><div class="btn-menu-item tgico-flag rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">گزارش</span></div><div class="btn-menu-item tgico-forward rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">به اشتراک گذاشتن مخاطب</span></div><div class="btn-menu-item tgico-lock rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">مسدود کردن کاربر</span></div><div class="btn-menu-item tgico-lockoff rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">رفع مسدودیت</span></div><div class="btn-menu-item tgico-group rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">ارتقاء به ابرگروه</span></div><div class="btn-menu-item tgico-delete danger rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">حذف</span></div></div></div></div><div class="pinned-audio pinned-container hide"><div class="pinned-container-wrapper rp"><div class="c-ripple"></div><button class="btn-icon tgico-pprevious active"><svg class="missing-icon" viewBox="0 0 24 24" preserveAspectRatio="xMidYMid meet"><g><path class="missing-icon-path" d="M6 6h2v12H6zm3.5 6l8.5 6V6z"></path></g></svg></button><button class="btn-icon active pinned-audio-ico tgico"></button><button class="btn-icon tgico-nnext active"><svg class="missing-icon" viewBox="0 0 24 24" preserveAspectRatio="xMidYMid meet"><g><path class="missing-icon-path" d="M6 18l8.5-6L6 6v12zM16 6v12h2V6h-2z"></path></g></svg></button><div class="pinned-audio-content pinned-container-content"><div class="pinned-audio-title pinned-container-title" dir="auto"></div><div class="pinned-audio-subtitle pinned-container-subtitle" dir="auto"></div></div><div class="pinned-audio-progress-wrapper"><div class="progress-line use-transform pinned-audio-progress"><div class="progress-line__filled"></div><input class="progress-line__seek" type="range" step="0.016666666666666666" min="0" max="1"></div></div><div class="pinned-container-wrapper-utils"><button class="btn-icon btn-menu-toggle active tgico-playback_1x"><div class="btn-menu play-speed-menu"><div class="btn-menu-item tgico-playback_05 rp"><div class="c-ripple"></div><span class="btn-menu-item-text"></span></div><div class="btn-menu-item tgico-playback_1x rp"><div class="c-ripple"></div><span class="btn-menu-item-text"></span></div><div class="btn-menu-item tgico-playback_15 rp"><div class="c-ripple"></div><span class="btn-menu-item-text"></span></div><div class="btn-menu-item tgico-playback_2x rp"><div class="c-ripple"></div><span class="btn-menu-item-text"></span></div></div></button><div class="player-volume btn-icon pinned-audio-volume active"><div class="pinned-audio-volume-tunnel"></div>
    <svg class="player-volume__icon" focusable="false" viewBox="0 0 24 24" aria-hidden="true"><path d="M3 9v6h4l5 5V4L7 9H3zm13.5 3c0-1.77-1.02-3.29-2.5-4.03v8.05c1.48-.73 2.5-2.25 2.5-4.02zM14 3.23v2.06c2.89.86 5 3.54 5 6.71s-2.11 5.85-5 6.71v2.06c4.01-.91 7-4.49 7-8.77s-2.99-7.86-7-8.77z"></path></svg>
    <div class="progress-line-container"><div class="progress-line"><div class="progress-line__filled" style="width: 100%;"></div><input class="progress-line__seek" type="range" step="0.01" min="0" max="1"></div></div></div><button class="pinned-container-close pinned-audio-close btn-icon tgico-close"></button></div></div></div></div><div class="bubbles scrolled-down"><div class="scrollable scrollable-y" style=""><div class="bubbles-inner has-rights is-chat is-channel"><div class="bubbles-date-group"><div class="bubble service is-date is-sticky"><div class="bubble-content"><div class="service-msg"><span class="i18n">۶ آذر</span></div></div></div><div class="sticky_sentinel sticky_sentinel--top"></div><div class="bubble is-in can-have-tail is-group-first is-group-last" data-mid="4822728703" data-peer-id="-51577627" data-timestamp="1764221725"><div class="bubble-content-wrapper"><div class="bubble-content"><div class="message" dir="auto">سلام ساعت۸
کوره۱ =۳/۶۳
کوره۲ =۰/۷۸
بالای۴۰میلی =۴/۴۹<span class="time tgico" title="1404/9/6, 09:05:25"><span class="i18n">۰۹:۰۵ قبل‌ازظهر</span><div class="inner tgico" title="1404/9/6, 09:05:25"><span class="i18n">۰۹:۰۵ قبل‌ازظهر</span></div></span></div><div data-peer-id="71137802" class="name" style="color: rgb(250, 121, 15);"><span class="peer-title" dir="auto" data-peer-id="71137802">عبدالله</span></div><svg viewBox="0 0 11 20" width="11" height="20" class="bubble-tail"><use href="#message-tail-filled"></use></svg></div><avatar-element class="user-avatar avatar-40" peer="71137802" dir="auto" data-color=""><img class="avatar-photo" src="blob:https://web.eitaa.com/1cac3512-5718-4bee-8c3c-f51020fd19f0"></avatar-element></div></div><div class="bubble hide-name photo is-album is-grouped is-in can-have-tail is-group-first" data-mid="4822990847" data-peer-id="-51577627" data-timestamp="1764223247"><div class="bubble-content-wrapper"><div class="bubble-content"><div class="message" dir="auto">باسلام خط خردایش درحال کار وبارگیری بارفولادازخردایش انجام میشود<span class="time tgico" title="1404/9/6, 09:30:47"><span class="i18n">۰۹:۳۰ قبل‌ازظهر</span><div class="inner tgico" title="1404/9/6, 09:30:47"><span class="i18n">۰۹:۳۰ قبل‌ازظهر</span></div></span></div><div class="attachment" style="width: 357px; height: 420px;"><div class="album-item grouped-item" data-mid="4822794239" data-peer-id="-51577627" style="width: 70.3081%; height: 100%; top: 0%; left: 0%; border-top-left-radius: inherit; border-bottom-left-radius: inherit;"><div class="album-item-media media-container"><img class="media-photo" src="blob:https://web.eitaa.com/d3614044-82c4-4bd6-89c2-fda56ae2501b"></div></div><div class="album-item grouped-item" data-mid="4822859775" data-peer-id="-51577627" style="width: 29.1317%; height: 33.0952%; top: 0%; left: 70.8683%; border-top-right-radius: inherit;"><div class="album-item-media media-container"><img class="media-photo" src="blob:https://web.eitaa.com/ca58e5de-1798-47b2-900c-3ffcad488e87"></div></div><div class="album-item gr
><div class="bubble-content-wrapper"><div class="bubble-content"><div class="message" dir="auto">شارژ سنگ برای کوره از خط انجام می‌شود و محصول مطلوب میباشد 
محصول در حال تولید خردایش یک و دو مطلوب و حدودا ۵ الی ۱۰ درصد قرمز دارد <span class="time tgico" title="1404/9/7, 09:09:21"><span class="i18n">۰۹:۰۹ قبل‌ازظهر</span><div class="inner tgico" title="1404/9/7, 09:09:21"><span class="i18n">۰۹:۰۹ قبل‌ازظهر</span></div></span></div><div class="attachment" style="width: 420px; height: 372px;"><div class="album-item grouped-item" data-mid="4824367103" data-peer-id="-51577627" style="width: 33.0952%; height: 49.7312%; top: 0%; left: 0%; border-top-left-radius: inherit;"><div class="album-item-media media-container"><img class="thumbnail media-photo" src="data:image/png;base64,..."></div></div><div class="album-item grouped-item" data-mid="4824432639" data-peer-id="-51577627" style="width: 33.0952%; height: 49.7312%; top: 0%; left: 33.5714%;"><div class="album-item-media media-container"><img class="thumbnail media-photo" src="data:image/png;base64,..."></div></div><div class="album-item grouped-item" data-mid="4824498175" data-peer-id="-51577627" style="width: 32.8571%; height: 49.7312%; top: 0%; left: 67.1429%; border-top-right-radius: inherit;"><div class="album-item-media media-container"><img class="thumbnail media-photo" src="data:image/png;base64,..."></div></div><div class="album-item grouped-item" data-mid="4824563711" data-peer-id="-51577627" style="width: 33.0952%; height: 49.7312%; top: 50.2688%; left: 0%; border-bottom-left-radius: inherit;"><div class="album-item-media media-container"><img class="thumbnail media-photo" src="data:image/png;base64,..."></div></div><div class="album-item grouped-item" data-mid="4824629247" data-peer-id="-51577627" style="width: 33.0952%; height: 49.7312%; top: 50.2688%; left: 33.5714%;"><div class="album-item-media media-container"><img class="thumbnail media-photo" src="data:image/png;base64,..."></div></div><div class="album-item grouped-item" data-mid="4824694783" data-peer-id="-51577627" style="width: 32.8571%; height: 49.7312%; top: 50.2688%; left: 67.1429%; border-bottom-right-radius: inherit;"><div class="album-item-media media-container"><img class="thumbnail media-photo" src="data:image/png;base64,..."></div></div></div><div data-peer-id="31087880" class="name" style="color: rgb(61, 114, 237);"><span class="peer-title" dir="auto" data-peer-id="31087880">98229 Morteza_Ahmadpor</span></div><svg viewBox="0 0 11 20" width="11" height="20" class="bubble-tail"><use href="#message-tail-filled"></use></svg></div><avatar-element class="user-avatar avatar-40" peer="31087880" dir="auto" data-color=""><img class="avatar-photo" src="blob:https://web.eitaa.com/88df43dd-4bde-4db2-8a19-a05c54f010e4"></avatar-element></div></div><div class="bubble hide-name video is-album is-grouped is-in can-have-tail is-group-first is-group-last" data-mid="4824825855" data-peer-id="-51577627" data-timestamp="1764320880"><div class="bubble-content-wrapper"><div class="bubble-content"><div class="message" dir="auto"><img src="assets/img/emoji/1f4aa.png" class="emoji" alt="💪"><img src="assets/img/emoji/1f4aa.png" class="emoji" alt="💪"> نضافت نیسان خارج از لیست نضافت، چون واقعا نمیشد داخلش بشینی از بس خاک گرفته بود <img src="assets/img/emoji/1f64b-200d-2642.png" class="emoji" alt="🙋‍♂️"><img src="assets/img/emoji/1f64b-200d-2642.png" class="emoji" alt="🙋‍♂️"><span class="time tgico" title="1404/9/7, 12:38:00"><span class="i18n">۱۲:۳۸ بعدازظهر</span><div class="inner tgico" title="1404/9/7, 12:38:00"><span class="i18n">۱۲:۳۸ بعدازظهر</span></div></span></div><div class="attachment" style="width: 420px; height: 318px;"><div class="album-item grouped-item" data-mid="4824760319" data-peer-id="-51577627" style="width: 56.9048%; height: 100%; top: 0%; left: 0%; border-top-left-radius: inherit; border-bottom-left-radius: inherit;"><div class="album-item-media media-container"><img class="thumbnail media-photo" src="data:image/png;base64,..."></div></div><div class="album-item grouped-item" data-mid="4824825855" data-peer-id="-51577627" style="width: 42.619%; height: 100%; top: 0%; left: 57.381%; border-top-right-radius: inherit; border-bottom-right-radius: inherit;"><div class="album-item-media media-container"><span class="video-time">20.32 MB, 0:48</span><span class="video-play tgico-largeplay btn-circle position-center"></span><img class="thumbnail media-photo" src="data:image/png;base64,..."></div></div></div><div data-peer-id="31087880" class="name" style="color: rgb(61, 114, 237);"><span class="peer-title" dir="auto" data-peer-id="31087880">98229 Morteza_Ahmadpor</span></div><svg viewBox="0 0 11 20" width="11" height="20" class="bubble-tail"><use href="#message-tail-filled"></use></svg></div><avatar-element class="user-avatar avatar-40" peer="31087880" dir="auto" data-color=""><img class="avatar-photo" src="blob:https://web.eitaa.com/88df43dd-4bde-4db2-8a19-a05c54f010e4"></avatar-element></div></div><div class="bubble is-reply is-in can-have-tail is-group-first is-group-last" data-mid="4824891391" data-peer-id="-51577627" data-timestamp="1764321324"><div class="bubble-content-wrapper"><div class="bubble-content"><div class="message" dir="auto">سلام
خداقوت جناب احمدپور
ممنون<img src="assets/img/emoji/1f340.png" class="emoji" alt="🍀">

یه ماسک میزدی حداقل<span class="time tgico" title="1404/9/7, 12:45:24"><span class="i18n">۱۲:۴۵ بعدازظهر</span><div class="inner tgico" title="1404/9/7, 12:45:24"><span class="i18n">۱۲:۴۵ بعدازظهر</span></div></span></div><div class="reply is-media"><div class="reply-border"></div><div class="reply-content"><div class="reply-media media-container"><img class="thumbnail media-photo" src="blob:https://web.eitaa.com/6f9294ea-5826-4fd3-a2c6-ba0698cffa92"></div><div class="reply-title" dir="auto"><span class="peer-title" dir="auto" data-peer-id="31087880" data-dialog="0" data-only-first-name="0" data-plain-text="0">98229 Morteza_Ahmadpor</span></div><div class="reply-subtitle" dir="auto"><img src="assets/img/emoji/1f4aa.png" class="emoji" alt="💪"><img src="assets/img/emoji/1f4aa.png" class="emoji" alt="💪"> نضافت نیسان خارج از لیست ن
بعدازظهر</span><div class="inner tgico" title="1404/9/7, 22:36:18"><span class="i18n">۱۰:۳۶ بعدازظهر</span></div></span></div><div class="attachment media-container media-container-fitted" style="width: 320px; height: 340px;"><img class="thumbnail media-photo" src="data:image/png;base64,..."><div class="media-container-aspecter" style="width: 255px; height: 340px;"><img class="thumbnail media-photo" src="data:image/png;base64,..."></div></div><div data-peer-id="71137802" class="name" style="color: rgb(250, 121, 15);"><span class="peer-title" dir="auto" data-peer-id="71137802">عبدالله</span></div><svg viewBox="0 0 11 20" width="11" height="20" class="bubble-tail"><use href="#message-tail-filled"></use></svg></div><avatar-element class="user-avatar avatar-40" peer="71137802" dir="auto" data-color=""><img class="avatar-photo" src="blob:https://web.eitaa.com/1cac3512-5718-4bee-8c3c-f51020fd19f0"></avatar-element></div></div><div class="bubble hide-name photo is-album is-grouped is-in can-have-tail is-group-last" data-mid="4826333183" data-peer-id="-51577627" data-timestamp="1764356811"><div class="bubble-content-wrapper" style=""><div class="bubble-content"><div class="message" dir="auto">شارج کوره مستقیم از خط ۰۵درحال انجام است<span class="time tgico" title="1404/9/7, 22:36:51"><span class="i18n">۱۰:۳۶ بعدازظهر</span><div class="inner tgico" title="1404/9/7, 22:36:51"><span class="i18n">۱۰:۳۶ بعدازظهر</span></div></span></div><div class="attachment" style="width: 420px; height: 279px;"><div class="album-item grouped-item" data-mid="4826267647" data-peer-id="-51577627" style="width: 49.7619%; height: 100%; top: 0%; left: 0%; border-top-left-radius: inherit; border-bottom-left-radius: inherit;"><div class="album-item-media media-container"><img class="media-photo" src="blob:https://web.eitaa.com/8358b3a2-7f86-4070-8f85-4fa054513cbc"></div></div><div class="album-item grouped-item" data-mid="4826333183" data-peer-id="-51577627" style="width: 49.7619%; height: 100%; top: 0%; left: 50.2381%; border-top-right-radius: inherit; border-bottom-right-radius: inherit;"><div class="album-item-media media-container"><img class="media-photo" src="blob:https://web.eitaa.com/b52532f0-1e64-4dfc-a303-735dda9be3d2"></div></div></div><div data-peer-id="71137802" class="name" style="color: rgb(250, 121, 15);"><span class="peer-title" dir="auto" data-peer-id="71137802">عبدالله</span></div><svg viewBox="0 0 11 20" width="11" height="20" class="bubble-tail"><use href="#message-tail-filled"></use></svg></div><avatar-element class="user-avatar avatar-40" peer="71137802" dir="auto" data-color=""><img class="avatar-photo" src="blob:https://web.eitaa.com/1cac3512-5718-4bee-8c3c-f51020fd19f0"></avatar-element></div></div></div><div class="bubbles-date-group"><div class="bubble service is-date"><div class="bubble-content"><div class="service-msg"><span class="i18n">امروز</span></div></div></div><div class="sticky_sentinel sticky_sentinel--top"></div><div class="bubble is-in can-have-tail is-group-first is-group-last" data-mid="4826398719" data-peer-id="-51577627" data-timestamp="1764361949"><div class="bubble-content-wrapper" style=""><div class="bubble-content"><div class="message" dir="auto">سلام کوره 1 ساعت 24 4.07 صدم شد...
کوره 2 ساعت 24 3.97 شد...<span class="time tgico" title="1404/9/8, 00:02:29"><span class="i18n">۱۲:۰۲ قبل‌ازظهر</span><div class="inner tgico" title="1404/9/8, 00:02:29"><span class="i18n">۱۲:۰۲ قبل‌ازظهر</span></div></span></div><div data-peer-id="33891335" class="name" style="color: rgb(137, 93, 213);"><span class="peer-title" dir="auto" data-peer-id="33891335">اسماعیل قوامی</span></div><svg viewBox="0 0 11 20" width="11" height="20" class="bubble-tail"><use href="#message-tail-filled"></use></svg></div><avatar-element class="user-avatar avatar-40" peer="33891335" dir="auto" data-color=""><img class="avatar-photo" src="blob:https://web.eitaa.com/0075cfaf-1ce9-45d1-93cd-683093b0a43e"></avatar-element></div></div></div></div></div></div><div class="chat-input" style=""><div class="chat-input-container"><div class="rows-wrapper chat-input-wrapper"><svg viewBox="0 0 11 20" width="11" height="20" class="bubble-tail"><use href="#message-tail-filled"></use></svg><div class="reply-wrapper"><button class="btn-icon rp"><div class="c-ripple"></div></button><button class="btn-icon tgico-close reply-cancel"></button><div class="btn-menu"><form><div class="btn-menu-item rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">Chat.Alert.Forward.Action.Show1</span><label class="checkbox-field checkbox-without-caption"><input class="checkbox-field-input" type="radio" name="author" value="1"><div class="checkbox-box"><div class="checkbox-box-border"></div><div class="checkbox-box-background"></div><svg class="checkbox-box-check" viewBox="0 0 24 24"><use href="#check" x="-1"></use></svg></div></label></div><div class="btn-menu-item rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">Chat.Alert.Forward.Action.Hide1</span><label class="checkbox-field checkbox-without-caption"><input class="checkbox-field-input" type="radio" name="author" value="0"><div class="checkbox-box"><div class="checkbox-box-border"></div><div class="checkbox-box-background"></div><svg class="checkbox-box-check" viewBox="0 0 24 24"><use href="#check" x="-1"></use></svg></div></label></div><hr></form><form><div class="btn-menu-item rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">Chat.Alert.Forward.Action.ShowCaption</span><label class="checkbox-field checkbox-without-caption"><input class="checkbox-field-input" type="radio" name="caption" value="1"><div class="checkbox-box"><div class="checkbox-box-border"></div><div class="checkbox-box-background"></div><svg class="checkbox-box-check" viewBox="0 0 24 24"><use href="#check" x="-1"></use></svg></div></label></div><div class="btn-menu-item rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">Chat.Alert.Forward.Action.HideCaption</span><label class="checkbox-field checkbox-without-caption"><input class="checkbox-field-input" type="radio" name="caption" value="0"><div class="checkbox-box"><div class="checkbox-box-border"></div><div class="checkbox-box-background"></div><svg class="checkbox-box-check" viewBox="0 0 24 24"><use href="#check" x="-1"></use></svg></div></label></div><hr></form><div class="btn-menu-item tgico-replace rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">هدایت به گفتگوی دیگر</span></div></div></div><div class="autocomplete-helper z-depth-1 stickers-helper"></div><div class="autocomplete-helper z-depth-1 emoji-helper"></div><div class="autocomplete-helper z-depth-1 autocomplete-peer-helper commands-helper"></div><div class="autocomplete-helper z-depth-1 autocomplete-peer-helper mentions-helper"></div><div class="autocomplete-helper z-depth-1 inline-helper"></div><div class="new-message-wrapper"><button class="btn-icon tgico-none toggle-emoticons"></button><div class="input-message-container"><div contenteditable="true" class="input-message-input scrollable scrollable-y i18n no-scrollbar" dir="auto" data-placeholder="پیام" style="transition-duration: 181ms; height: 37px;"></div><div contenteditable="true" class="input-message-input scrollable scrollable-y input-field-input-fake i18n" data-placeholder="پیام"></div></div><button class="btn-icon tgico-scheduled btn-scheduled float hide show"></button><button class="btn-icon tgico-botcom toggle-reply-markup float hide show"></button><div class="btn-icon btn-menu-toggle attach-file tgico-attach"><div class="btn-menu top-left"><div class="btn-menu-item tgico-image rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">عکس یا ویدیو</span></div><div class="btn-menu-item tgico-document rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">فایل</span></div></div></div><div class="record-time"></div><input type="file" multiple="" style="display: none;"></div></div><div class="fake-wrapper fake-rows-wrapper"></div><div class="fake-wrapper fake-selection-wrapper"></div><button class="btn-circle btn-corner z-depth-1 bubbles-corner-button bubbles-go-down tgico-arrow_down rp"><div class="c-ripple"></div><span class="badge badge-24 badge-primary badge-gray"></span></button><button class="btn-circle btn-corner z-depth-1 bubbles-corner-button bubbles-go-mention tgico-mention rp"><div class="c-ripple"></div><span class="badge badge-24 badge-primary"></span></button><button class="btn-icon tgico-delete danger btn-circle z-depth-1 btn-record-cancel rp"><div class="c-ripple"></div></button><div class="btn-send-container"><div class="record-ripple"></div><button class="btn-icon tgico-none btn-circle z-depth-1 btn-send animated-button-icon rp record">
    <span class="tgico tgico-send"></span>
    <span class="tgico tgico-schedule"></span>
    <span class="tgico tgico-check"></span>
    <span class="tgico tgico-microphone"></span>
    <div class="c-ripple"></div></button><div class="btn-menu menu-send top-left"><div class="btn-menu-item tgico-mute rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">ارسال بی‌صدا</span></div><div class="btn-menu-item tgico-schedule rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">زمان‌بندی پیام</span></div><div class="btn-menu-item tgico-schedule rp"><div class="c-ripple"></div><span class="i18n btn-menu-item-text">تنظیم کردن یادآور</span></div></div></div></div></div></div></div></div><div class="tabs-tab sidebar sidebar-right main-column" id="column-right"><div class="sidebar-content sidebar-slider tabs-container" data-animation="navigation"><div class="tabs-tab sidebar-slider-item shared-media-container profile-container can-add-members"><div class="sidebar-header"><button class="btn-icon sidebar-close-button"><div class="animated-close-icon"></div></button><div class="transition slide-fade" data-animation="slide-fade"><div class="transition-item active"><div class="sidebar-header__title"><span class="i18n">پروفایل</span></div><button class="btn-icon tgico-edit rp hide"><div class="c-ripple"></div></button></div><div class="transition-item"><div class="sidebar-header__title"><span class="i18n">رسانه‌های اشتراکی</span></div></div></div></div><div class="sidebar-content"><div class="scrollable scrollable-y no-parallax"><div class="profile-content"><div class="sidebar-left-section-container"><div class="sidebar-left-section no-delimiter"><div class="sidebar-left-section-content"><avatar-element class="profile-avatar avatar-120" dialog="1" clickable="set" peer="-51577627" dir="auto" data-color="green">کآ</avatar-element><div class="profile-name"><span class="peer-title" dir="auto" data-peer-id="-51577627" data-dialog="1">کنترل کیفیت و آزمایشگاه </span></div><div class="profile-subtitle"><span class="i18n">⁨8⁩ عضو</span></div><div class="row row-with-icon row-with-padding row-clickable hover-effect rp" style="display: none;"><div class="c-ripple"></div><div class="row-subtitle" dir="auto"><span class="i18n">تلفن</span></div><div class="row-title tgico tgico-phone" dir="auto"> </div></div><div class="row row-with-icon row-with-padding row-clickable hover-effect rp" style="display: none;"><div class="c-ripple"></div><div class="row-subtitle" dir="auto"><span class="i18n">نام کاربری</span></div><div class="row-title tgico tgico-username" dir="auto"> </div></div><div class="row row-with-icon row-with-padding row-clickable hover-effect rp" style="display: none;"><div class="c-ripple"></div><div class="row-subtitle" dir="auto"><span class="i18n">بیوگرافی</span></div><div class="row-title tgico tgico-info pre-wrap" dir="auto"> </div></div><div class="row row-with-icon row-with-padding row-clickable hover-effect rp" style="display: none;"><div class="c-ripple"></div><div class="row-subtitle" dir="auto"><span class="i18n">لینک</span></div><div class="row-title tgico tgico-link" dir="auto"> </div></div><label class="row row-with-toggle row-with-icon row-with-padding row-clickable hover-effect rp"><div class="c-ripple"></div><div class="row-subtitle" dir="auto"></div><div class="row-title-row"><div class="row-title tgico tgico-unmute" dir="auto"><span class="i18n">اعلان‌ها</span></div><div class="row-title row-title-right"><label class="checkbox-field checkbox-without-caption checkbox-field-toggle disable-hover"><input class="checkbox-field-input" type="checkbox"><div class="checkbox-toggle"></div></label></div></div></label></div></div></div><div class="search-super"><div class="search-super-tabs-scrollable menu-horizontal-scrollable sticky"><div class="scrollable scrollable-x search-super-nav-scrollable"><nav class="search-super-tabs menu-horizontal-div"><div class="menu-horizontal-div-item rp active"><span><span class="i18n">اعضا</span><i></i></span><div class="c-ripple"></div></div><div class="menu-horizontal-div-item rp"><span><span class="i18n">رسانه</span><i></i></span><div class="c-ripple"></div></div><div class="menu-horizontal-div-item rp"><span><span class="i18n">فایل‌ها</span><i></i></span><div class="c-ripple"></div></div><div class="menu-horizontal-div-item rp"><span><span class="i18n">لینک‌ها</span><i></i></span><div class="c-ripple"></div></div><div class="menu-horizontal-div-item rp"><span><span class="i18n">موسیقی</span><i></i></span><div class="c-ripple"></div></div><div class="menu-horizontal-div-item rp hide"><span><span class="i18n">صدا</span><i></i></span><div class="c-ripple"></div></div></nav></div></div><div class="search-super-tabs-container tabs-container" data-animation="tabs"><div class="search-super-container-members tabs-tab active"><div class="search-super-content-members"><ul class="chatlist"><li class="chatlist-chat" data-peer-id="47877019"><avatar-element dialog="0" peer="47877019" dir="auto" data-color="orange" class="dialog-avatar avatar-48">AZ</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="47877019" data-dialog="0" data-only-first-name="0" data-plain-text="0">Abas Zadeh</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><span class="i18n">آخرین بازدید ⁨1⁩ دقیقه پیش</span></span></p></div></li><li class="chatlist-chat" data-peer-id="33891335"><avatar-element dialog="0" peer="33891335" dir="auto" data-color="" class="dialog-avatar avatar-48"><img class="avatar-photo" src="blob:https://web.eitaa.com/0075cfaf-1ce9-45d1-93cd-683093b0a43e"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="33891335" data-dialog="0" data-only-first-name="0" data-plain-text="0">اسماعیل قوامی</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><span class="i18n">آخرین بازدید ⁨9⁩ دقیقه پیش</span></span></p></div></li><li class="chatlist-chat" data-peer-id="7002842"><avatar-element dialog="0" peer="7002842" dir="auto" data-color="red" class="dialog-avatar avatar-48">مر</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="7002842" data-dialog="0" data-only-first-name="0" data-plain-text="0">محمد رضا</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><span class="i18n">آخرین بازدید ⁨29⁩ دقیقه پیش</span></span></p></div></li><li class="chatlist-chat" data-peer-id="31087880"><avatar-element dialog="0" peer="31087880" dir="auto" data-color="" class="dialog-avatar avatar-48"><img class="avatar-photo" src="blob:https://web.eitaa.com/88df43dd-4bde-4db2-8a19-a05c54f010e4"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="31087880" data-dialog="0" data-only-first-name="0" data-plain-text="0">98229 Morteza_Ahmadpor</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><span class="i18n">آخرین بازدید ⁨30⁩ دقیقه پیش</span></span></p></div></li><li class="chatlist-chat" data-peer-id="71137802"><avatar-element dialog="0" peer="71137802" dir="auto" data-color="" class="dialog-avatar avatar-48"><img class="avatar-photo" src="blob:https://web.eitaa.com/1cac3512-5718-4bee-8c3c-f51020fd19f0"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="71137802" data-dialog="0" data-only-first-name="0" data-plain-text="0">عبدالله</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><span class="i18n">آخرین بازدید ⁨1⁩ ساعت پیش</span></span></p></div></li><li class="chatlist-chat" data-peer-id="24284733"><avatar-element dialog="0" peer="24284733" dir="auto" data-color="" class="dialog-avatar avatar-48"><img class="avatar-photo" src="blob:https://web.eitaa.com/67fa08c3-8260-4244-9929-fe17bb1151ad"></avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="24284733" data-dialog="0" data-only-first-name="0" data-plain-text="0">Mohammad Karimi</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><span class="i18n">آخرین بازدید ⁨3⁩ ساعت پیش</span></span></p></div></li><li class="chatlist-chat" data-peer-id="3032351"><avatar-element dialog="0" peer="3032351" dir="auto" data-color="red" class="dialog-avatar avatar-48">بآ</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="3032351" data-dialog="0" data-only-first-name="0" data-plain-text="0">بهنام  ابولقاسمی آزمایشگاه</span></span><span class="dialog-title-details"><span class="i18n">مالک</span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><span class="i18n">آخرین بازدید ⁨4⁩ ساعت پیش</span></span></p></div></li><li class="chatlist-chat" data-peer-id="43490431"><avatar-element dialog="0" peer="43490431" dir="auto" data-color="blue" class="dialog-avatar avatar-48">ام</avatar-element><div class="user-caption"><p class="dialog-title"><span class="user-title tgico"><span class="eitaa-dialog eitaa-chat"></span><span class="peer-title" dir="auto" data-peer-id="43490431" data-dialog="0" data-only-first-name="0" data-plain-text="0">اکبر  هدایت مقدم</span></span><span class="dialog-title-details"><span class="message-status sending-status"></span><span class="message-time"></span></span></p><p class="dialog-subtitle"><span class="user-last-message" dir="auto"><span class="i18n">آخرین بازدید ⁨14⁩ ساعت پیش</span></span></p></div></li></ul></div></div><div class="search-super-container-media tabs-tab"><div class="search-super-content-media"></div><div class="preloader">
  <svg xmlns="http://www.w3.org/2000/svg" class="preloader-circular" viewBox="25 25 50 50">
  <circle class="preloader-path" cx="50" cy="50" r="20" fill="none" stroke-miterlimit="10"></circle>
  </svg></div></div><div class="search-super-container-files tabs-tab"><div class="search-super-content-files"></div><div class="preloader">
  <svg xmlns="http://www.w3.org/2000/svg" class="preloader-circular" viewBox="25 25 50 50">
  <circle class="preloader-path" cx="50" cy="50" r="20" fill="none" stroke-miterlimit="10"></circle>
  </svg></div></div><div class="search-super-container-links tabs-tab"><div class="search-super-content-links"></div><div class="preloader">
  <svg xmlns="http://www.w3.org/2000/svg" class="preloader-circular" viewBox="25 25 50 50">
  <circle class="preloader-path" cx="50" cy="50" r="20" fill="none" stroke-miterlimit="10"></circle>
  </svg></div></div><div class="search-super-container-music tabs-tab"><div class="search-super-content-music"></div><div class="preloader">
  <svg xmlns="http://www.w3.org/2000/svg" class="preloader-circular" viewBox="25 25 50 50">
  <circle class="preloader-path" cx="50" cy="50" r="20" fill="none" stroke-miterlimit="10"></circle>
  </svg></div></div><div class="search-super-container-voice tabs-tab"><div class="search-super-content-voice"></div><div class="preloader">
  <svg xmlns="http://www.w3.org/2000/svg" class="preloader-circular" viewBox="25 25 50 50">
  <circle class="preloader-path" cx="50" cy="50" r="20" fill="none" stroke-miterlimit="10"></circle>
  </svg></div></div></div></div></div></div><button class="btn-circle btn-corner z-depth-1 tgico-addmember_filled rp"><div class="c-ripple"></div></button></div></div></div></div></div><div class="emoji-dropdown" id="emoji-dropdown" style="display:none"><div class="emoji-container"><div class="tabs-container"><div class="tabs-tab emoji-padding"><nav class="menu-horizontal-div no-stripe"><button class="menu-horizontal-div-item btn-icon tgico-recent rp"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item btn-icon tgico-smile rp"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item btn-icon tgico-animals rp"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item btn-icon tgico-eats rp"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item btn-icon tgico-car rp"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item btn-icon tgico-sport rp"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item btn-icon tgico-lamp rp"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item btn-icon tgico-flag rp"><div class="c-ripple"></div></button></nav><div class="emoticons-content" id="content-emoji"></div></div><div class="tabs-tab stickers-padding"><div class="menu-wrapper"><nav class="menu-horizontal-div no-stripe justify-start"><button class="menu-horizontal-div-item btn-icon tgico-recent active"></button></nav></div><div class="emoticons-content" id="content-stickers"></div></div><div class="tabs-tab gifs-padding"><div class="emoticons-content" id="content-gifs"><div class="gifs-masonry"></div></div></div></div></div><div class="emoji-tabs menu-horizontal-div no-stripe"><button class="menu-horizontal-div-item emoji-tabs-search justify-self-start btn-icon tgico-search rp" data-tab="-1"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item emoji-tabs-emoji btn-icon tgico-smile rp" data-tab="0"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item emoji-tabs-stickers btn-icon tgico-stickers rp" data-tab="1"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item emoji-tabs-gifs btn-icon tgico-gifs rp" data-tab="2"><div class="c-ripple"></div></button> <button class="menu-horizontal-div-item emoji-tabs-delete justify-self-end btn-icon tgico-deleteleft rp" data-tab="-1"><div class="c-ripple"></div></button></div></div></div><script src="npm.sentry.742fcf210fa98831c80f.chunk.js"></script><script src="npm.sentry-internal.0547fe09a4f1f36fb8ed.chunk.js"></script><script src="npm.pako.2d4fc265131a1c56bfed.chunk.js"></script><script src="main.0e161fe37b3fa00cb7f1.bundle.js"></script><div id="notify-sound"></div><div style="display: none;"></div></body>"""

# %%
soup = BeautifulSoup(chat, "lxml")

# %%
# کانتینر اصلی
container = soup.find("div", class_="bubbles-inner has-rights is-chat is-channel")

# %%
# همه‌ی پیام‌ها داخل کانتینر
messages = container.find_all("div", class_="bubble")  # یا کلاس واقعی پیام‌ها

# %%
chat_data = []
for msg in messages:
    # متن پیام
    message_tag = msg.find("div", class_="message")
    text = message_tag.get_text(" ", strip=True) if message_tag else None

    # زمان پیام
    time_tag = msg.find("span", class_="time")
    time = time_tag.get_text(strip=True) if time_tag else None

    # فرستنده
    sender_tag = msg.find("span", class_="peer-title")
    sender = sender_tag.get_text(strip=True) if sender_tag else None

    chat_data.append({
        "time": time,
        "sender": sender,
        "text": text
    })

for item in chat_data:
    print(item)
# Out:
# {'time': None, 'sender': None, 'text': None}
# {'time': '۰۹:۰۵ قبل\u200cازظهر۰۹:۰۵ قبل\u200cازظهر', 'sender': 'عبدالله', 'text': 'سلام ساعت۸\nکوره۱ =۳/۶۳\nکوره۲ =۰/۷۸\nبالای۴۰میلی =۴/۴۹ ۰۹:۰۵ قبل\u200cازظهر ۰۹:۰۵ قبل\u200cازظهر'}
# {'time': '۰۹:۳۰ قبل\u200cازظهر۰۹:۳۰ قبل\u200cازظهر', 'sender': 'عبدالله', 'text': 'باسلام خط خردایش درحال کار وبارگیری بارفولادازخردایش انجام میشود ۰۹:۳۰ قبل\u200cازظهر ۰۹:۳۰ قبل\u200cازظهر'}
# {'time': '۰۹:۳۱ قبل\u200cازظهر۰۹:۳۱ قبل\u200cازظهر', 'sender': 'عبدالله', 'text': 'خط تولید درحال حاضر متوقف است ۰۹:۳۱ قبل\u200cازظهر ۰۹:۳۱ قبل\u200cازظهر'}
# {'time': '۰۹:۳۱ قبل\u200cازظهر۰۹:۳۱ قبل\u200cازظهر', 'sender': 'عبدالله', 'text': 'شارج هاپرکوره ازخردایش۲درحال انجام است ۰۹:۳۱ قبل\u200cازظهر ۰۹:۳۱ قبل\u200cازظهر'}
# {'time': '۰۱:۲۵ بعدازظهر۰۱:۲۵ بعدازظهر', 'sender': 'عبدالله', 'text': 'سلام ساعت۱۲ \nکوره۱ =۶/۷۰\nکوره۲ =۲/۸۵ ۰۱:۲۵ بعدازظهر ۰۱:۲۵ بعدازظهر'}
# ...
